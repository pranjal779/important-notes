# %%
import pandas as pd

# Escape Character
data = {'Hexadecimal Character': [r'\b', r'\a', r'\C-x', r'\cx', r'\e', r'\v', r'\s', r'\n', r'\t', r'\x'], # ['\b', '\a', '\C-x', '\cx', '\e', '\v', '\s', '\n', '\t', '\x'],
        'Backslash Notation': ['0x08', '0x07', ' ', ' ', '0x1b', '0x0b', '0x20', '0x0a', '0x09', ' '],
        'Description': ['Backspace', 'Bell or alert', 'Control x', 'Control x', 'Escape', 'Vertical tab', 'Space', 'New line', 'Tab', 'Character x']}
df = pd.DataFrame(data)
df


# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 1-2: truncated \xXX escape
# Out:
#   Hexadecimal Character Backslash Notation    Description
# 0                    \b               0x08      Backspace
# 1                    \a               0x07  Bell or alert
# 2                  \C-x                         Control x
# 3                   \cx                         Control x
# 4                    \e               0x1b         Escape
# 5                    \v               0x0b   Vertical tab
# 6                    \s               0x20          Space
# 7                    \n               0x0a       New line
# 8                    \t               0x09            Tab
# 9                    \x                       Character x

# %%
# String Formatting Operator

data02 = {'Format Symbol': ['%d', '%c', '%o', '%i', '%u', '%x', '%X', '%f', '%e', '%E'],
          'Conversion': ['Signed decimal integer', 'Character', 'Octal integer', 'Signed decimal integer', 'Unsigned decimal integer', 'Hexadecimal integer (lowercase letters)', 'Hexadecimal integer (uppercase letters)', 'Floating point real number', 'Exponential notation (with lower "e")', 'Exponential notation (with lower "E")']}

df = pd.DataFrame(data02)
df
# Out:
#   Format Symbol                               Conversion
# 0            %d                   Signed decimal integer
# 1            %c                                Character
# 2            %o                            Octal integer
# 3            %i                   Signed decimal integer
# 4            %u                 Unsigned decimal integer
# 5            %x  Hexadecimal integer (lowercase letters)
# 6            %X  Hexadecimal integer (uppercase letters)
# 7            %f               Floating point real number
# 8            %e    Exponential notation (with lower "e")
# 9            %E    Exponential notation (with lower "E")
